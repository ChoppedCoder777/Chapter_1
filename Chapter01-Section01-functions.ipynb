# %% [markdown]
# ### Chapter 1, Section 1: Functions
# - Problems: Paper (1,3,7,9,15,17,35,37,77,85).
# - Problems: Jupyter (9,85).
# - Below is the code for problem 9, 85

# %% [markdown]
# - import `numpy` for numerical operations.
# - import `matplotlib.pyplot` for plotting.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Get the set of x values from -a to -a with n values
# - The range of x values are from -sqrt(5) to +sqrt(5), but there are numerical problems with this. (e.g. try a = 5**0.5)

# %%
a = 2.236
npoints = 250
x = np.linspace(-a, a, npoints)

# %%
#print(x) #Remove the first hashtag to see the values of x.

# %% [markdown]
# - Define the functionss

# %%
ypos = (5-x**2)**0.5 + 3

# %%
yneg = -(5-x**2)**0.5 + 3

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal', adjustable='box')
plt.plot(x, ypos, color='red')
plt.plot(x, yneg, color='green')
plt.title('Plot of $x^2 + (y-3)^2 = 5$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %%
a = 2
npoints = 250
x = np.linspace(-a, a, npoints)

# %%
y = 1 + 3*x**2 - x**4

# %%
#print(y) #Remove the first hashtag to see the values of y.

# %% [markdown]
# - Plot the function on the domain [-a,a]
# - Add a title, labels, grid, labels, and legend

# %%
plt.plot(x, y,color='red')
plt.title('Plot of $ 1 + 3*x^2 - x^4$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
