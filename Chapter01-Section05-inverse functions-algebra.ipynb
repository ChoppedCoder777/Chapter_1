# %% [markdown]
# ### Chapter 1, Section 5: This Section is divided into three lessons. This lesson deals with algebraic inverse functions.
# - Problems: Paper (5, 7 , 9, 23, 25).
# - Problems: Jupyter (23, 25). Problem 23 is done for you.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %%
x_vals = np.linspace(0, 1, 400)
y_vals = 1 - x_vals**2

y_vals_inv = np.linspace(0, 1, 400)
x_vals_inv = np.sqrt(1 - y_vals_inv)

plt.plot(x_vals, y_vals, label='f(x) = 1 - x²', color='red')
plt.plot(y_vals_inv, x_vals_inv, label='Inverse: f⁻¹(y)', color='green')
plt.plot(x_vals, x_vals, color='black', linestyle=':', label='y = x')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Function and Its Inverse')
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
sym.init_printing()
x, y = sym.symbols('x y')

# %%
f = (1+ sym.exp(-x))
eq = sym.Eq(y, f)
inverse_solved = sym.solve(eq, x)
print ("equation")
display (eq)
print("inverse")
display (inverse_solved)
# Out:
# equation
#          -x
# y = 1 + ℯ
# inverse
# ⎡   ⎛  1  ⎞⎤
# ⎢log⎜─────⎟⎥
# ⎣   ⎝y - 1⎠⎦

# %%
inverse_solved = sym.solve(eq, x)[0]

# %%
f_lambdified = sym.lambdify(x, f, 'numpy')
inverse_lambdified = sym.lambdify(y, inverse_solved, 'numpy')

# %%
x_vals = np.linspace(0.01, 10, 400)
y_vals = f_lambdified(x_vals)
inverse_vals = inverse_lambdified(y_vals)

# %%
import numpy as np
import matplotlib.pyplot as plt
x1 = np.linspace(-1, 10, 400)  
x2 = np.linspace(-1, 7, 400)   
f_x = 2 + np.sqrt(x1 + 1)
f_inv_x = (x2 - 2)**2 - 1
plt.figure(figsize=(10, 6))
plt.plot(x1, f_x, label='f(x) = 2 + √(x + 1)', color='blue')
plt.plot(x2, f_inv_x, label='f⁻¹(x) = (x - 2)² - 1', color='green')
plt.title('Graphs of f(x) and f⁻¹(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

# %% [markdown]
# #not sure why this didnt work as i graphed the funciton and its inverse. i have the paper hw but i didnt put it here because i did this at school and dont have a phone
